# %%
import pandas as pd

df = pd.read_csv('/Users/eric5805/Documents/1-YEAR-TRAINING/Projects/Car Sales/data/raw/raw.csv')

# %%
df.head(5)
# Out:
#   Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0         Ford      Fiesta          1.0    Petrol                 2002
# 1      Porsche  718 Cayman          4.0    Petrol                 2016
# 2         Ford      Mondeo          1.6    Diesel                 2014
# 3       Toyota        RAV4          1.8    Hybrid                 1988
# 4           VW        Polo          1.0    Petrol                 2006
#
#    Mileage  Price
# 0   127300   3074
# 1    57850  49704
# 2    39190  24072
# 3   210814   1705
# 4   127869   4101

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Engine size', 'Fuel type',
#        'Year of manufacture', 'Mileage', 'Price'],
#       dtype='object')

# %%
df.dtypes # no change
# Out:
# Manufacturer            object
# Model                   object
# Engine size            float64
# Fuel type               object
# Year of manufacture      int64
# Mileage                  int64
# Price                    int64
# False                   object
# dtype: object

# %%
df.isna().sum() # 0
# Out:
# Manufacturer           0
# Model                  0
# Engine size            0
# Fuel type              0
# Year of manufacture    0
# Mileage                0
# Price                  0
# False                  0
# dtype: int64

# %%
df[['Model','Manufacturer']]
# Out:
#             Model Manufacturer
# 0          Fiesta         Ford
# 1      718 Cayman      Porsche
# 2          Mondeo         Ford
# 3            RAV4       Toyota
# 4            Polo           VW
# ...           ...          ...
# 49995          M5          BMW
# 49996       Prius       Toyota
# 49997      Mondeo         Ford
# 49998       Focus         Ford
# 49999        Golf           VW
#
# [50000 rows x 2 columns]
