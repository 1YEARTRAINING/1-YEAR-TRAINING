# %%
import pandas as pd

df = pd.read_csv('/Users/eric5805/Documents/1-YEAR-TRAINING/Projects/Car Sales/data/raw/raw.csv')

# %%
df['Manufacturer'] = df['Manufacturer'].replace('VW', 'Volkswagen')

# %%
df.to_csv('/Users/eric5805/Documents/1-YEAR-TRAINING/Projects/Car Sales/data/processed/processed.csv', index=False)
